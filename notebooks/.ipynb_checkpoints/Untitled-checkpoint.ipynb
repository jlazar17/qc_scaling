# %%
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/research/qc_scaling/notebooks`

# %%
using Makie
using CairoMakie
using HDF5
using Glob
using Statistics
using ColorSchemes
# Out:
# [ Info: Precompiling Makie [ee78f7c6-11fb-53f2-987a-cfe4a2b5a57a] (cache misses: wrong dep version loaded (2), wrong source (14))
# [ Info: Precompiling CairoMakie [13f3f980-e62b-5c42-98c6-ff1f3baf88f0] (cache misses: wrong dep version loaded (18))

# %%
include("plotting_boilerplate.jl")

# %%
filenames = glob("????????.h5", "/Users/jlazar/Downloads/eight_qubit_res/");

# %%
d = Dict()
for filename in filenames
   x = h5open(filename) do h5f
       nstate, pzero = attrs(h5f["results"])["nstate"], attrs(h5f["results"])["pzero"]
       maxacc = maximum(h5f["results/accuracies"][:])
       nstate, pzero, maxacc
   end
   k = x[1], x[2]
   maxacc = x[3]
   if ~(k in keys(d))
       d[k] = []
   end
   push!(d[k], maxacc)
end

# %%
out = zeros((11, 8, 3))
for (idx, pzero) in enumerate(0:0.1:1)
   for (jdx, nstate) in enumerate(150:50:500)
       res = d[(nstate, pzero)]
       out[idx, jdx, :] = quantile(res, [0.16, 0.5, 0.84])
   end
end

# %%
pzeros = 0:0.1:1
nstates = 150:50:500
# Out:
# 150:50:500

# %%
function mutual_information(f)
   if f==1 || f==0
       return 1
   end
   return 1 - log(2, f) * log(2, 1-f)
end
# Out:
# mutual_information (generic function with 1 method)

# %%
fig = Figure()
ax = Axis(
    fig[1, 1],
    limits=(0, 1, nothing, nothing),
    xlabel=L"p_{\mathrm{zero}}",
    ylabel=L"f"
)

colors = cgrad(:roma, length(nstates), categorical=true)

for (idx, (nstate, color)) in enumerate(zip(nstates, colors))
    lines!(ax, pzeros, out[:, idx, 2], label=L"N_{\mathrm{state}}=%$(nstate)", color=color)
    band!(ax, pzeros, out[:, idx, 1], out[:, idx, 3], color=(color, 0.2))
end

axislegend(ax, nbanks=4, labelsize=15, position=:ct)

fig

# %%
fig = Figure(size=(600, 400))
ax = Axis(
    fig[1, 1],
    limits=(150, 500, nothing, nothing),
    xlabel=L"N_{\mathrm{state}}",
    ylabel=L"\mathrm{MI}(f_{\mathrm{med.}}) / N_{\mathrm{state}}",
)

colors = cgrad(:roma, length(pzeros), categorical=true)

for (idx, (color, pzero)) in enumerate(zip(colors, pzeros))
   lines!(
        ax,
        nstates,
        mutual_information.(out[idx, :, 2]) ./ nstates,
        color=color,
        label=L"p_{\mathrm{zero}} = %$(pzero)"
    )
end

fig[1, 2] = Legend(fig, ax)


fig

# %%
fig = Figure()
ax = Axis(fig[1, 1])

xs = 0:0.01:5

lines!(ax, xs, sigmoid.(xs.-1.5, 0.0001) - sigmoid.(xs .- 3.3, 0.0001), label="Discrete")
lines!(ax, xs, sigmoid.(xs.-1.5, 0.05) - sigmoid.(xs .- 3.3, 0.05), label="Smoothed")
lines!(ax, xs, sigmoid.(xs.-1.5, 0.1) - sigmoid.(xs .- 3.3, 0.1), label="Very smooth")

axislegend(ax)

fig
